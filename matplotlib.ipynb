# %% [markdown]
# <a href="https://colab.research.google.com/github/LIKHITHAGOPALASETTI/python-new/blob/module-5/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["chimtu", "chimki", "nishi", "mannu"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
#pie chart
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["chimtu", "chimki", "nishi", "mannu"]

plt.pie(y, labels = mylabels)
plt.show()

# %%
#bargraph
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,7,5,3,5])
y=np.array([5,10,8,1,6])
plt.bar(x,y,ls='-',color='k')

plt.show()
